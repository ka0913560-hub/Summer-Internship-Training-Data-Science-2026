# %%
NUMPY

# %%
It is basically Numericaln Python

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\roaming\python\python313\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
a=np.array([1,2,3])

# %%
a
# Out:
# array([1, 2, 3])

# %% [raw]
# print(a)

# %%
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %%
b=np.array([[12,33,33],[2,1,3]])

# %%
print(type(b))
# Out:
# <class 'list'>

# %%
b.shape
# Out:
# (2, 3)

# %%
R, C= Rows & Columns 
Rows=2
Columns=3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 R, C= Rows & Columns
#       2 Rows=2
#       3 Columns=3
#
# NameError: name 'Rows' is not defined

# %%
c=np.array([1,2,3])
d=np.array([2,4,5])

# %%
+,-,*,/,//,%,**
# Out:
#   Cell In[11], line 1
#     +,-,*,/,//,%,**
#      ^
# SyntaxError: invalid syntax

# %%
c+d
# Out:
# array([3, 6, 8])

# %%
c-d
# Out:
# array([-1, -2, -2])

# %%
c*d
# Out:
# array([ 2,  8, 15])

# %%
c/d
# Out:
# array([0.5, 0.5, 0.6])

# %%
c//d
# Out:
# array([0, 0, 0])

# %%
c%d
# Out:
# array([1, 2, 3])

# %%
c**d
# Out:
# array([  1,  16, 243])

# %%
a=10
b=10
a is b
# Out:
# True

# %%
a=[1,2,3]
b=[2,3,1]
a is b
# Out:
# False

# %%
a=np.array([[1,2,3],[2,3,4]])
b=np.array([[2,3,4],[3,4,6]])

# %%
a+b
# Out:
# array([[ 3,  5,  7],
#        [ 5,  7, 10]])

# %%
a-b
# Out:
# array([[-1, -1, -1],
#        [-1, -1, -2]])

# %%
a*b
# Out:
# array([[ 2,  6, 12],
#        [ 6, 12, 24]])

# %%
a/d
# Out:
# array([[0.5 , 0.5 , 0.6 ],
#        [1.  , 0.75, 0.8 ]])

# %%
a**d
# Out:
# array([[   1,   16,  243],
#        [   4,   81, 1024]])

# %%
a%d
# Out:
# array([[1, 2, 3],
#        [0, 3, 4]])

# %%
a//d
# Out:
# array([[0, 0, 0],
#        [1, 0, 0]])

# %%
a=np.array([[1,2,3],[2,3,4]])
b=np.array([[2,3,4],[3,4,6]])
np.dot(a,b.T)
# Out:
# array([[20, 29],
#        [29, 42]])

# %%
np.transpose(b)
# Out:
# array([[2, 3],
#        [3, 4],
#        [4, 6]])

# %%
np.dot(a,b.T)
# Out:
# array([[20, 29],
#        [29, 42]])

# %%
arr=np.array([[1,2,3],[4,5,6]])
print(arr.shape)
print(arr.size)
print(arr.ndim)
print(arr.dtype)
# Out:
# (2, 3)
# 6
# 2
# int64

# %%
print(np.sum(arr))
print(np.min(arr))
print(np.max(arr))
print(np.sum(arr,axis=0))
print(np.sum(arr,axis=1))
# Out:
# 21
# 1
# 6
# [5 7 9]
# [ 6 15]
