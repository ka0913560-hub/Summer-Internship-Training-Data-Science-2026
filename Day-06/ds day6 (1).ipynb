# %%
#Image grading

# %%
pip install PILLOW
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt
#to display img on screen

# %%
img=Image.open("s3.jpeg")

img=np.array(img)
img[:,:,0]=np.clip(img[:,:,0]+90.255,0)    #img brightness change  b

plt.imshow(img)     #to display img
plt.aixis("off")    #axis hide (X aur Y axis hata dega)
plt.show()          #show final img
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 img=Image.open("s3.jpeg")
# ----> 3 img=np.array(img)
#       4 img[:,:,0]=np.clip(img[:,:,0]+90.255,0)    #img brightness change  b
#       6 plt.imshow(img)     #to display img
#
# NameError: name 'np' is not defined

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open(r"s3.jpeg")  #img=variable
img_arr=np.array(img)       #img changed into an array

plt.imshow(img_arr)

# %%
plt.imshow(img_arr[0:200,0:350])  #for first quadrant

# %%
plt.imshow(img_arr[0:200,350:])  #for second quadrant

# %%
plt.imshow(img_arr[200:,0:350,])  #for third quadrant

# %%
plt.imshow(img_arr[200:,350:]) #for fourth quadrant

# %%
#R=0, G-1 B-2,,, To remove color
plt.imshow(img_arr[200:,350:,1])

# %%
#R=0, G-1 B-2,,, To remove color
plt.imshow(img_arr[200:,350:,0])

# %%
#R=0, G-1 B-2,,, To remove color
plt.imshow(img_arr[200:,350:,2])

# %%
#R=0, G-1 B-2,,, To remove color
plt.imshow(img_arr[200:,0:350,2]) #in third quadrant

# %%
# Project on numpy-
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
img=Image.open(r"s3.jpeg")
img_arr=np.array(img)
img_arr[250:,370:,1]=0    #fourth
img_arr[0:250,0:370,2]=0 #first
img_arr[0:250,370:,0]=0  #second
img_arr[250:,0:370,0]=250#third

plt.imshow(img_arr)

# %%
#pandas

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.DataFrame({
    "Name":["Khush","Divyank","Jigyasa","Chandrika","Dashika"],"Marks":[10,12,13,14,15]
})

# %%
df
# Out:
#         Name  Marks
# 0      Khush     10
# 1    Divyank     12
# 2    Jigyasa     13
# 3  Chandrika     14
# 4    Dashika     15
