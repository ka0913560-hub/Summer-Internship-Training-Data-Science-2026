# %% [markdown]
# # Artificial Neural Network (ANN)
#
# ## What is ANN?
#
# Artificial Neural Network (ANN) is a Machine Learning model inspired by the human brain. It learns patterns by adjusting weights and biases through multiple training iterations.
#
# ---
#
# # Human Brain vs ANN
#
# | Human Brain | ANN |
# |-------------|-----|
# | Neuron | Artificial Neuron |
# | Synapse | Weight |
# | Signal | Input |
# | Brain Decision | Output |
#
# ---
#
# # ANN Architecture
#
# ```
# Input Layer
#       │
#       ▼
# Hidden Layer
#       │
#       ▼
# Output Layer
# ```
#
# ---
#
# # Artificial Neuron
#
# Each neuron performs:
#
# \[
# Z = \sum (W \times X) + B
# \]
#
# where
#
# - X = Input
# - W = Weight
# - B = Bias
# - Z = Weighted Sum
#
# ---
#
# # Activation Function
#
# Output is
#
# \[
# A = f(Z)
# \]
#
# Common activation functions
#
# - ReLU
# - Sigmoid
# - Tanh
# - Softmax
#
# ---
#
# # Example
#
# Inputs
#
# ```
# X1 = 2
# X2 = 3
# ```
#
# Weights
#
# ```
# W1 = 0.5
# W2 = 0.4
# ```
#
# Bias
#
# ```
# B = 1
# ```
#
# Weighted Sum
#
# \[
# Z=(2×0.5)+(3×0.4)+1
# \]
#
# \[
# Z=1+1.2+1
# \]
#
# \[
# Z=3.2
# \]
#
# ---
#
# # ReLU Activation
#
# Formula
#
# \[
# ReLU(x)=max(0,x)
# \]
#
# Since
#
# ```
# Z=3.2
# ```
#
# Output
#
# ```
# 3.2
# ```
#
# ---
#
# # Sigmoid Activation
#
# Formula
#
# \[
# \sigma(x)=\frac{1}{1+e^{-x}}
# \]
#
# For
#
# ```
# Z=3.2
# ```
#
# Output
#
# ```
# 0.96
# ```
#
# ---
#
# # Forward Propagation
#
# ```
# Input
#
# ↓
#
# Multiply by Weights
#
# ↓
#
# Add Bias
#
# ↓
#
# Activation Function
#
# ↓
#
# Prediction
# ```
#
# ---
#
# # Loss Function
#
# Measures prediction error.
#
# Mean Squared Error
#
# \[
# Loss=(Actual-Predicted)^2
# \]
#
# Example
#
# ```
# Actual = 1
#
# Prediction = 0.8
# ```
#
# Loss
#
# \[
# (1-0.8)^2=0.04
# \]
#
# ---
#
# # Backpropagation
#
# Steps
#
# ```
# Calculate Loss
#
# ↓
#
# Find Error
#
# ↓
#
# Calculate Gradient
#
# ↓
#
# Update Weights
#
# ↓
#
# Repeat
# ```
#
# ---
#
# # Weight Update Formula
#
# \[
# NewWeight=OldWeight-\eta\times Gradient
# \]
#
# Example
#
# ```
# Old Weight = 0.50
#
# Gradient = 0.20
#
# Learning Rate = 0.10
# ```
#
# New Weight
#
# ```
# 0.50-(0.10×0.20)
#
# =
#
# 0.48
# ```
#
# ---
#
# # Training Loop
#
# ```
# Input Data
#
# ↓
#
# Forward Propagation
#
# ↓
#
# Prediction
#
# ↓
#
# Loss Calculation
#
# ↓
#
# Backpropagation
#
# ↓
#
# Weight Update
#
# ↓
#
# Repeat Until Loss is Minimum
# ```
#
# ---
#
# # Hyperparameters
#
# - Learning Rate
# - Epochs
# - Batch Size
# - Hidden Layers
# - Neurons
# - Activation Function
#
# ---
#
# # Advantages
#
# - Learns complex patterns
# - High accuracy
# - Works for classification & regression
# - Foundation of Deep Learning
#
# ---
#
# # Limitations
#
# - Requires large dataset
# - High computation
# - Can overfit
# - Hyperparameter tuning required
#
# ---
#
# # Applications
#
# - Face Recognition
# - Medical Diagnosis
# - Stock Prediction
# - Fraud Detection
# - Speech Recognition
# - Recommendation Systems
#
# ---
#
# # Interview Questions
#
# ### What is ANN?
#
# ANN is a network of interconnected artificial neurons that learns patterns by adjusting weights and biases.
#
# ### What is Weight?
#
# Weight represents the importance of an input feature.
#
# ### What is Bias?
#
# Bias shifts the activation function and helps improve learning.
#
# ### Why Activation Function?
#
# To introduce non-linearity so the network can learn complex relationships.
#
# ### Why Backpropagation?
#
# To minimize loss by updating weights using gradients.
#
# ---
#
# # Complete ANN Flow
#
# ```
# Input
#    ↓
# Weights
#    ↓
# Weighted Sum
#    ↓
# Bias
#    ↓
# Activation Function
#    ↓
# Prediction
#    ↓
# Loss
#    ↓
# Backpropagation
#    ↓
# Weight Update
#    ↓
# Repeat
# ```

# %% [markdown]
# # Activation Functions in Deep Learning
#
# ## What is an Activation Function?
#
# An **Activation Function** is a mathematical function that decides **whether a neuron should be activated or not**. It introduces **non-linearity** into the neural network, enabling it to learn complex patterns.
#
# Without an activation function, a deep neural network behaves like a simple **Linear Regression Model**, regardless of the number of hidden layers.
#
# ---
#
# ## Why Do We Need Activation Functions?
#
# Suppose we have three layers:
#
# ```
# Layer 1
#
# Y = 2X + 5
#
# ↓
#
# Layer 2
#
# Y = 4Y + 2
#
# ↓
#
# Layer 3
#
# Y = 6Y + 1
# ```
#
# After simplifying,
#
# ```
# Y = AX + B
# ```
#
# It is still a **linear equation**.
#
# **Conclusion:** Without an activation function, multiple hidden layers provide no additional learning capability.
#
# ---
#
# ## Working of an Activation Function
#
# ```
# Input Features (X)
#
#         │
#
#         ▼
#
# Multiply with Weights (W)
#
#         │
#
#         ▼
#
# Add Bias (b)
#
#         │
#
#         ▼
#
# Z = WX + b
#
#         │
#
#         ▼
#
# Activation Function
#
#         │
#
#         ▼
#
# Output (A)
# ```
#
# Formula:
#
# ```
# Z = WX + b
#
# A = Activation(Z)
# ```
#
# ---
#
# # Types of Activation Functions
#
# ```
# Activation Functions
#
# │
#
# ├── Linear
#
# ├── Binary Step
#
# ├── Sigmoid
#
# ├── Tanh
#
# ├── ReLU
#
# ├── Leaky ReLU
#
# ├── PReLU
#
# ├── ELU
#
# ├── SELU
#
# ├── Softplus
#
# ├── Softsign
#
# ├── Swish
#
# ├── GELU
#
# ├── Mish
#
# └── Softmax
# ```
#
# ---
#
# # 1. Linear Activation Function
#
# ## Formula
#
# ```
# f(x) = x
# ```
#
# ## Range
#
# ```
# (-∞ , +∞)
# ```
#
# ## Graph
#
# ```
#       /
#
#     /
#
#   /
#
# /
# ```
#
# ## Advantages
#
# - Very simple
# - Used for continuous values
#
# ## Disadvantages
#
# - Cannot learn non-linear patterns
#
# ## Use Case
#
# Regression Output Layer
#
# Example:
#
# - House Price Prediction
# - Temperature Prediction
# - Salary Prediction
#
# Keras
#
# ```python
# Dense(1, activation='linear')
# ```
#
# ---
#
# # 2. Binary Step Function
#
# ## Formula
#
# ```
# If x ≥ 0
#
# Output = 1
#
# Else
#
# Output = 0
# ```
#
# ## Range
#
# ```
# 0 or 1
# ```
#
# ## Graph
#
# ```
# 1 ─────────────
#
# |
#
# |
#
# 0──────────────
# ```
#
# ## Advantages
#
# - Very simple
#
# ## Disadvantages
#
# - Gradient = 0
# - Cannot use Backpropagation
#
# ## Use Case
#
# Historical Perceptron only
#
# Not used in modern Deep Learning.
#
# ---
#
# # 3. Sigmoid Function
#
# ## Formula
#
# ```
# σ(x)=1/(1+e^-x)
# ```
#
# ## Range
#
# ```
# 0 to 1
# ```
#
# ## Graph
#
# ```
# 1 ─────────
#
#         /
#
#       /
#
#     /
#
# 0────────────
# ```
#
# ## Advantages
#
# - Produces probability
# - Smooth curve
#
# ## Disadvantages
#
# - Vanishing Gradient
# - Slow convergence
#
# ## Best Initializer
#
# ```
# Glorot Uniform (Xavier)
# ```
#
# ## Use Case
#
# Binary Classification Output Layer
#
# Examples
#
# - Spam Detection
# - Cancer Prediction
# - Customer Churn
#
# Keras
#
# ```python
# Dense(1, activation='sigmoid')
# ```
#
# ---
#
# # 4. Tanh Function
#
# ## Formula
#
# ```
# tanh(x)
# ```
#
# ## Range
#
# ```
# -1 to +1
# ```
#
# ## Graph
#
# ```
# 1 ───────
#
#      /
#
# ----0------
#
#     \
#
# -1────────
# ```
#
# ## Advantages
#
# - Zero-centered output
# - Better than Sigmoid
#
# ## Disadvantages
#
# - Vanishing Gradient
#
# ## Best Initializer
#
# ```
# Glorot Uniform
# ```
#
# ## Use Case
#
# Older Hidden Layers
#
# RNN (internally)
#
# Keras
#
# ```python
# Dense(64, activation='tanh')
# ```
#
# ---
#
# # 5. ReLU (Rectified Linear Unit)
#
# ## Formula
#
# ```
# f(x)=max(0,x)
# ```
#
# ## Range
#
# ```
# 0 to +∞
# ```
#
# ## Graph
#
# ```
#       /
#
#      /
#
# ____/
# ```
#
# Example
#
# Input
#
# ```
# -8
#
# -2
#
# 0
#
# 4
#
# 7
# ```
#
# Output
#
# ```
# 0
#
# 0
#
# 0
#
# 4
#
# 7
# ```
#
# ## Advantages
#
# - Fast
# - Easy computation
# - No Vanishing Gradient (positive side)
#
# ## Disadvantages
#
# - Dying ReLU Problem
#
# ## Best Initializer
#
# ```
# He Normal
#
# He Uniform
# ```
#
# ## Use Case
#
# Default Hidden Layer Activation
#
# CNN
#
# ANN
#
# Keras
#
# ```python
# Dense(128, activation='relu')
# ```
#
# ---
#
# # 6. Leaky ReLU
#
# ## Formula
#
# ```
# Positive
#
# x
#
# Negative
#
# 0.01x
# ```
#
# Example
#
# Input
#
# ```
# -10
# ```
#
# Output
#
# ```
# -0.1
# ```
#
# ## Advantages
#
# - Solves Dying ReLU
#
# ## Best Initializer
#
# ```
# He Normal
# ```
#
# Keras
#
# ```python
# Dense(64)
#
# LeakyReLU(alpha=0.01)
# ```
#
# ---
#
# # 7. PReLU
#
# ## Formula
#
# ```
# Positive
#
# x
#
# Negative
#
# αx
# ```
#
# Difference
#
# ```
# α is learned automatically.
# ```
#
# ## Advantages
#
# - Better than Leaky ReLU
#
# ## Use Case
#
# Advanced Deep Networks
#
# ---
#
# # 8. ELU
#
# ## Formula
#
# Positive
#
# ```
# x
# ```
#
# Negative
#
# ```
# α(e^x−1)
# ```
#
# ## Advantages
#
# - Smooth
# - Faster convergence
#
# ## Best Initializer
#
# ```
# He Normal
# ```
#
# ---
#
# # 9. SELU
#
# Self-Normalizing Activation
#
# ## Advantages
#
# Automatically maintains
#
# ```
# Mean
#
# Variance
# ```
#
# ## Best Initializer
#
# ```
# Lecun Normal
# ```
#
# ---
#
# # 10. Softplus
#
# ## Formula
#
# ```
# ln(1+e^x)
# ```
#
# Smooth version of ReLU.
#
# ---
#
# # 11. Softsign
#
# ## Formula
#
# ```
# x/(1+|x|)
# ```
#
# Range
#
# ```
# -1 to +1
# ```
#
# Alternative to Tanh.
#
# ---
#
# # 12. Swish
#
# ## Formula
#
# ```
# x × Sigmoid(x)
# ```
#
# Developed by Google.
#
# ## Use Case
#
# EfficientNet
#
# ---
#
# # 13. GELU
#
# ## Formula
#
# ```
# xΦ(x)
# ```
#
# where
#
# ```
# Φ(x)
# ```
#
# is the Gaussian CDF.
#
# ## Advantages
#
# - Better gradient flow
# - Smooth activation
#
# ## Use Case
#
# - GPT
# - BERT
# - Transformers
# - Vision Transformer (ViT)
#
# ---
#
# # 14. Mish
#
# ## Formula
#
# ```
# x × tanh(Softplus(x))
# ```
#
# ## Advantages
#
# - Smooth
# - Better gradient flow
#
# Mostly used in research models.
#
# ---
#
# # 15. Softmax
#
# ## Formula
#
# ```
# e^x / Σe^x
# ```
#
# ## Output
#
# Probability Distribution
#
# Example
#
# ```
# Cat      = 0.70
#
# Dog      = 0.20
#
# Horse    = 0.10
# ```
#
# Total
#
# ```
# 0.70 + 0.20 + 0.10 = 1
# ```
#
# ## Advantages
#
# - Converts outputs into probabilities
# - Sum is always equal to 1
#
# ## Use Case
#
# Multi-Class Classification
#
# Examples
#
# - Digit Recognition
# - Face Recognition
# - Image Classification
#
# Keras
#
# ```python
# Dense(10, activation='softmax')
# ```
#
# ---
#
# # Activation Function Summary
#
# | Activation | Output Range | Best Use |
# |------------|--------------|----------|
# | Linear | (-∞,+∞) | Regression Output |
# | Binary Step | 0,1 | Perceptron (Old) |
# | Sigmoid | 0 to 1 | Binary Classification |
# | Tanh | -1 to 1 | Hidden Layer (Old) |
# | ReLU | 0 to +∞ | Hidden Layers |
# | Leaky ReLU | (-∞,+∞) | Hidden Layers |
# | PReLU | (-∞,+∞) | Advanced Networks |
# | ELU | (-α,+∞) | Hidden Layers |
# | SELU | (-∞,+∞) | Self-Normalizing Networks |
# | Softplus | (0,+∞) | Smooth ReLU |
# | Softsign | -1 to 1 | Alternative to Tanh |
# | Swish | (-∞,+∞) | EfficientNet |
# | GELU | (-∞,+∞) | Transformers / LLMs |
# | Mish | (-∞,+∞) | Research Models |
# | Softmax | 0 to 1 | Multi-Class Output |
#
# ---
#
# # Activation Function Selection
#
# | Problem | Hidden Layer | Output Layer |
# |----------|--------------|--------------|
# | Regression | ReLU | Linear |
# | Binary Classification | ReLU | Sigmoid |
# | Multi-Class Classification | ReLU | Softmax |
# | Multi-Label Classification | ReLU | Sigmoid |
# | CNN | ReLU | Softmax |
# | RNN/LSTM | Tanh + Sigmoid | Depends on Task |
# | Transformers (GPT/BERT) | GELU | Softmax |
#
# ---
#
# # Interview Questions
#
# ### Q1. Why is an activation function required?
#
# To introduce **non-linearity**, allowing the neural network to learn complex relationships.
#
# ---
#
# ### Q2. Which activation function is most commonly used in hidden layers?
#
# **ReLU**
#
# ---
#
# ### Q3. Which activation function is used for Binary Classification?
#
# **Sigmoid**
#
# ---
#
# ### Q4. Which activation function is used for Multi-Class Classification?
#
# **Softmax**
#
# ---
#
#
# ---
#
# # Shortcut for Interviews
#
# ```
# Hidden Layer
# ↓
#
# ReLU
#
# ↓
#
# Binary Output
# ↓
#
# Sigmoid
#
# ↓
#
# Multi-Class Output
# ↓
#
# Softmax
#
# ↓
#
# Regression Output
# ↓
#
# Linear
#
# ↓
#
# LLMs / Transformers
# ↓
#
# GELU
# ```

# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras.models as km
from keras.models import Sequential
from keras import activations, initializers, regularizers, constraints
from keras.layers import Dense, Activation

# %%
dataset=pd.read_csv("winequality-red.csv")

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset["quality"].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
X = dataset.drop(columns=["quality"])
y = dataset['quality']

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state =123)

# %%
# sc = StandardScaler()
# train_X = sc.fit_transform(train_X)
# test_X = sc.transform(test_X)

# %%
train_X.shape
# Out:
# (1119, 11)

# %%
model = Sequential()
model.add(Dense(units = 11, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
model.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'linear'))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │            28 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 237 (948.00 B)
#  Trainable params: 237 (948.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
print(train_X.shape)
print(train_y.shape)
# Out:
# (1119, 11)
# (1119,)

# %%
model.fit(train_X, train_y, epochs=50, batch_size=32, validation_split=0.1)

# Evaluate the model
mse = model.evaluate(test_X, test_y)
print(f'Test Mean Squared Error: {mse}')
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 32.6676 - val_loss: 33.1833
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31.5582 - val_loss: 30.4623
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26.6251 - val_loss: 16.1282
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 10.7616 - val_loss: 6.0336
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 5.6608 - val_loss: 5.5259
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 5.4380 - val_loss: 4.5752
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 4.0660 - val_loss: 4.0552
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7730 - val_loss: 3.2256
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9009 - val_loss: 2.6550
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3827 - val_loss: 1.9623
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 1.6761 - val_loss: 1.4982
# ...

# %%
predictions = model.predict(test_X)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step

# %%
predictions
# Out:
# array([[6.384028 ],
#        [5.1620226],
#        [5.133809 ],
#        [6.0850797],
#        [5.2796526],
#        [5.5791063],
#        [5.983398 ],
#        [5.4899654],
#        [5.5519357],
#        [5.70878  ],
#        [5.030721 ],
#        [6.6184545],
#        [5.576085 ],
#        [5.7305613],
#        [5.877007 ],
#        [6.2160225],
#        [5.086139 ],
#        [5.8668647],
#        [5.8160043],
#        [5.353025 ],
#        [5.7539716],
#        [5.576085 ],
#        [5.6674657],
#        [5.2751517],
#        [5.3393373],
#        [5.2747455],
#        [5.9298515],
#        [5.687236 ],
#        [5.971483 ],
#        [5.6565657],
#        [5.021521 ],
#        [6.195519 ],
#        [5.340935 ],
#        [5.083453 ],
#        [6.079784 ],
#        [4.960629 ],
#        [5.558144 ],
#        [6.090303 ],
#        [5.207503 ],
#        [5.1304116],
#        [5.469047 ],
#        [5.9354663],
#        [6.0374007],
#        [5.605926 ],
#        [5.47228  ],
# ...
